# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["WANDB_START_METHOD"] = "thread"

# %%
from datasets import Dataset, load_metric
import mmh3
import numpy as np
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, TrainingArguments, Trainer, DataCollatorForTokenClassification
import torch
import random

# %%
MAX_LEN_CHARS = 256*3

# %%
df_t = pd.read_csv("data/eng_sentences.tsv", sep="\t", names=["id", "lang", "text"])
df_t = df_t[df_t["text"].str.len() < MAX_LEN_CHARS]

# shuffle
df_t["id"] = df_t["text"].map(lambda x: mmh3.hash64(x.encode('utf8'))[0])
df_t = df_t.sort_values("id")
len(df_t)
# Out:
# 1582094

# %%
df_o = pd.read_csv("data/oss.tsv", sep="\t", names=["text"])
df_o = df_o[df_o["text"].str.len() < MAX_LEN_CHARS]

# shuffle
df_o["id"] = df_o["text"].map(lambda x: mmh3.hash64(x.encode('utf8'))[0])
df_o = df_o.sort_values("id")
len(df_o)
# Out:
# 66939

# %%
df_g = pd.read_csv("data/gutenberg.tsv", sep="\t", names=["text"])
df_g = df_g[df_g["text"].str.len() < MAX_LEN_CHARS]

# shuffle
df_g["id"] = df_g["text"].map(lambda x: mmh3.hash64(x.encode('utf8'))[0])
df_g = df_g.sort_values("id")
len(df_g)
# Out:
# 4102516

# %%
df_t.head(1)
# Out:
#                           id lang  \
# 1123557 -9223326714129212706  eng
#
#                                                       text
# 1123557  Tom told everybody that he didn't know what to...

# %%
df_o.head(1)
# Out:
#                                                     text                   id
# 12494  Sometimes you need to access a type passed as ... -9222670596738368818

# %%
df_g.head(1)
# Out:
#                                                       text  \
# 1285889  To persons standing alone on a hill during a c...
#
#                           id
# 1285889 -9223366647700897551

# %%
train_t_size = 1500000
train_o_size = 66939-20000
train_g_size = 4000000
val_size = 10000
test_size = 10000
assert(train_t_size + val_size + test_size <= len(df_t["text"]))
assert(train_o_size + val_size + test_size <= len(df_o["text"]))
assert(train_g_size + val_size + test_size <= len(df_g["text"]))

train_text = list(df_t["text"])[:train_t_size] + list(df_o["text"])[:train_o_size] + list(df_g["text"])[:train_g_size]
random.Random(4).shuffle(train_text)

val_text = list(df_t["text"])[-val_size-test_size:-test_size] + list(df_o["text"])[-val_size-test_size:-test_size] \
+ list(df_g["text"])[-val_size-test_size:-test_size]

test_text = list(df_t["text"])[-test_size:] + list(df_o["text"])[-test_size:] + list(df_g["text"])[-test_size:]

len(train_text), len(val_text), len(test_text)
# Out:
# (5546939, 30000, 30000)

# %%
train_text[:3]
# Out:
# ["I usually go to Australia for my summer vacation, but this year I'm planning to go to New Zealand.",
#  'Their grandmothers had suffered the hardships of frontier life, had known the horrors of savage warfare when the beautiful valleys of the Connecticut and the Merrimack were threaded with Indian trails from Canada to the white settlements.',
#  'He was observant, truthful, and kindly--perhaps the chief requisites in a good story-teller.']

# %%
label_list = ['O', 'B-COMMA']
label_encoding_dict = {'O': 0, 'B-COMMA': 1}

model_checkpoint = "roberta-base"
batch_size = 64

# %%
if "roberta" in model_checkpoint:
    tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, add_prefix_space=True)
else:
    tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(label_list))
args = TrainingArguments(
    "comma-" + model_checkpoint,
    evaluation_strategy="steps",
    eval_steps=500,
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size//2,
    num_train_epochs=5,
    weight_decay=1e-5,
)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForTokenClassification: ['lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def to_dataset(texts):
    tokens, tags = [], []
    for text in texts:
        text_tokens, text_tags = [], []
        for token in text.split(" "):
            if "," in token:
                tag = "B-COMMA"
                token = token.replace(",", "")
            else:
                tag = "O"
            text_tokens.append(token)
            text_tags.append(tag)
        tokens.append(text_tokens)
        tags.append(text_tags)
    return Dataset.from_pandas(pd.DataFrame({
        'tokens': tokens, 'tags': tags
    }))

# %%
train_dataset = to_dataset(train_text)
val_dataset = to_dataset(val_text)
test_dataset = to_dataset(test_text)

train_dataset
# Out:
# Dataset({
#     features: ['tokens', 'tags'],
#     num_rows: 5546939
# })

# %%
def tokenize_and_align_labels(examples):
    label_all_tokens = True
    tokenized_inputs = tokenizer(list(examples["tokens"]), truncation=True, is_split_into_words=True)

    labels = []
    for i, label in enumerate(examples["tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)
            elif label[word_idx] == '0':
                label_ids.append(0)
            elif word_idx != previous_word_idx:
                label_ids.append(label_encoding_dict[label[word_idx]])
            else:
                label_ids.append(label_encoding_dict[label[word_idx]] if label_all_tokens else -100)
            previous_word_idx = word_idx
        labels.append(label_ids)
        
    tokenized_inputs["labels"] = labels
    return tokenized_inputs

train_tokenized_datasets = train_dataset.map(tokenize_and_align_labels, batched=True)
test_tokenized_datasets = test_dataset.map(tokenize_and_align_labels, batched=True)
# Out:
#   0%|          | 0/5547 [00:00<?, ?ba/s]
#   0%|          | 0/30 [00:00<?, ?ba/s]

# %%
data_collator = DataCollatorForTokenClassification(tokenizer)
metric = load_metric("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [[label_list[p] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]
    true_labels = [[label_list[l] for (p, l) in zip(prediction, label) if l != -100] for prediction, label in zip(predictions, labels)]

    results = metric.compute(predictions=true_predictions, references=true_labels)
    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"]
    }
    
trainer = Trainer(
    model,
    args,
    train_dataset=train_tokenized_datasets,
    eval_dataset=test_tokenized_datasets,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# /opt/conda/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 5546939
#   Num Epochs = 5
#   Instantaneous batch size per device = 64
#   Total train batch size (w. parallel, distributed & accumulation) = 512
#   Gradient Accumulation steps = 1
#   Total optimization steps = 54170
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: firefish (use `wandb login --relogin` to force relogin)
# wandb version 0.12.15 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.14
# Run data is saved locally in <code>/root/shared/punct/wandb/run-20220424_081452-d2fn8fhs</code>
# Syncing run <strong><a href="https://wandb.ai/firefish/huggingface/runs/d2fn8fhs" target="_blank">comma-roberta-base</a></strong> to <a href="https://wandb.ai/firefish/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='54170' max='54170' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [54170/54170 8:53:43, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.095100</td>
#       <td>0.048070</td>
#       <td>0.845389</td>
#       <td>0.778862</td>
#       <td>0.810763</td>
#       <td>0.975888</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.067700</td>
#       <td>0.044202</td>
#       <td>0.832788</td>
#       <td>0.823090</td>
#       <td>0.827911</td>
#       <td>0.977308</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.064700</td>
#       <td>0.041961</td>
#       <td>0.835176</td>
#       <td>0.835588</td>
#       <td>0.835382</td>
#       <td>0.978161</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.063100</td>
#       <td>0.040636</td>
#       <td>0.849924</td>
#       <td>0.826523</td>
#       <td>0.838060</td>
#       <td>0.978817</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.061400</td>
#       <td>0.040822</td>
#       <td>0.862119</td>
#       <td>0.814182</td>
#       <td>0.837465</td>
#       <td>0.979042</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.060600</td>
#       <td>0.039742</td>
#       <td>0.856817</td>
#       <td>0.825401</td>
#       <td>0.840816</td>
#       <td>0.979274</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.059900</td>
#       <td>0.039496</td>
#       <td>0.851967</td>
#       <td>0.837361</td>
#       <td>0.844601</td>
#       <td>0.979565</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.059600</td>
#       <td>0.038367</td>
#       <td>0.852529</td>
#       <td>0.845260</td>
#       <td>0.848879</td>
#       <td>0.980042</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.058800</td>
#       <td>0.037484</td>
#       <td>0.864797</td>
#       <td>0.833030</td>
#       <td>0.848616</td>
#       <td>0.980290</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.058400</td>
#       <td>0.037699</td>
#       <td>0.865854</td>
#       <td>0.829036</td>
#       <td>0.847045</td>
#       <td>0.980144</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.057900</td>
#       <td>0.037246</td>
#       <td>0.860621</td>
#       <td>0.839224</td>
#       <td>0.849788</td>
#       <td>0.980324</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.057700</td>
#       <td>0.037034</td>
#       <td>0.857960</td>
#       <td>0.844542</td>
#       <td>0.851198</td>
#       <td>0.980418</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.057400</td>
#       <td>0.036647</td>
#       <td>0.859472</td>
#       <td>0.847997</td>
#       <td>0.853696</td>
#       <td>0.980725</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.057200</td>
#       <td>0.036618</td>
#       <td>0.854779</td>
#       <td>0.856793</td>
#       <td>0.855785</td>
#       <td>0.980850</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.057000</td>
#       <td>0.036566</td>
#       <td>0.859706</td>
#       <td>0.849366</td>
#       <td>0.854505</td>
#       <td>0.980818</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.056300</td>
#       <td>0.036256</td>
#       <td>0.863385</td>
#       <td>0.844205</td>
#       <td>0.853687</td>
#       <td>0.980809</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.056300</td>
#       <td>0.036214</td>
#       <td>0.872789</td>
#       <td>0.834893</td>
#       <td>0.853420</td>
#       <td>0.980981</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.056000</td>
#       <td>0.035878</td>
#       <td>0.858686</td>
#       <td>0.854505</td>
#       <td>0.856590</td>
#       <td>0.981025</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.055700</td>
#       <td>0.035752</td>
#       <td>0.865082</td>
#       <td>0.849164</td>
#       <td>0.857049</td>
#       <td>0.981214</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.055700</td>
#       <td>0.035637</td>
#       <td>0.872107</td>
#       <td>0.840346</td>
#       <td>0.855932</td>
#       <td>0.981239</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.055300</td>
#       <td>0.036069</td>
#       <td>0.859639</td>
#       <td>0.854527</td>
#       <td>0.857075</td>
#       <td>0.981100</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.054800</td>
#       <td>0.035982</td>
#       <td>0.873226</td>
#       <td>0.835409</td>
#       <td>0.853899</td>
#       <td>0.981042</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.053200</td>
#       <td>0.035551</td>
#       <td>0.873482</td>
#       <td>0.839044</td>
#       <td>0.855917</td>
#       <td>0.981266</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.053000</td>
#       <td>0.035866</td>
#       <td>0.877052</td>
#       <td>0.836845</td>
#       <td>0.856477</td>
#       <td>0.981400</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.052800</td>
#       <td>0.035735</td>
#       <td>0.869533</td>
#       <td>0.848110</td>
#       <td>0.858688</td>
#       <td>0.981488</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.053000</td>
#       <td>0.035594</td>
#       <td>0.873034</td>
#       <td>0.839515</td>
#       <td>0.855947</td>
#       <td>0.981260</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.052900</td>
#       <td>0.035754</td>
#       <td>0.868633</td>
#       <td>0.845731</td>
#       <td>0.857029</td>
#       <td>0.981287</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.052500</td>
#       <td>0.035444</td>
#       <td>0.861032</td>
#       <td>0.857399</td>
#       <td>0.859212</td>
#       <td>0.981366</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.052400</td>
#       <td>0.035603</td>
#       <td>0.864932</td>
#       <td>0.850376</td>
#       <td>0.857592</td>
#       <td>0.981271</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.052500</td>
#       <td>0.035324</td>
#       <td>0.870528</td>
#       <td>0.847459</td>
#       <td>0.858839</td>
#       <td>0.981525</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.052500</td>
#       <td>0.035032</td>
#       <td>0.873655</td>
#       <td>0.845484</td>
#       <td>0.859339</td>
#       <td>0.981644</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.052200</td>
#       <td>0.034987</td>
#       <td>0.873768</td>
#       <td>0.845260</td>
#       <td>0.859277</td>
#       <td>0.981640</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.052000</td>
#       <td>0.035090</td>
#       <td>0.872645</td>
#       <td>0.844878</td>
#       <td>0.858537</td>
#       <td>0.981536</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.052200</td>
#       <td>0.034743</td>
#       <td>0.871898</td>
#       <td>0.847638</td>
#       <td>0.859597</td>
#       <td>0.981637</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.051900</td>
#       <td>0.034451</td>
#       <td>0.870516</td>
#       <td>0.853248</td>
#       <td>0.861795</td>
#       <td>0.981851</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.051700</td>
#       <td>0.035068</td>
#       <td>0.855709</td>
#       <td>0.870167</td>
#       <td>0.862877</td>
#       <td>0.981659</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.052000</td>
#       <td>0.034856</td>
#       <td>0.860474</td>
#       <td>0.863525</td>
#       <td>0.861997</td>
#       <td>0.981664</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.052100</td>
#       <td>0.034737</td>
#       <td>0.864179</td>
#       <td>0.861057</td>
#       <td>0.862615</td>
#       <td>0.981811</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.051800</td>
#       <td>0.034776</td>
#       <td>0.871723</td>
#       <td>0.846157</td>
#       <td>0.858750</td>
#       <td>0.981540</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.051800</td>
#       <td>0.034455</td>
#       <td>0.874358</td>
#       <td>0.847773</td>
#       <td>0.860860</td>
#       <td>0.981826</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.051700</td>
#       <td>0.034722</td>
#       <td>0.873570</td>
#       <td>0.849792</td>
#       <td>0.861517</td>
#       <td>0.981882</td>
#     </tr>
#     <tr>
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-500
# Configuration saved in comma-roberta-base/checkpoint-500/config.json
# Model weights saved in comma-roberta-base/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-1000
# Configuration saved in comma-roberta-base/checkpoint-1000/config.json
# Model weights saved in comma-roberta-base/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-1000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-1500
# Configuration saved in comma-roberta-base/checkpoint-1500/config.json
# Model weights saved in comma-roberta-base/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-1500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-2000
# Configuration saved in comma-roberta-base/checkpoint-2000/config.json
# Model weights saved in comma-roberta-base/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-2000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-2500
# Configuration saved in comma-roberta-base/checkpoint-2500/config.json
# Model weights saved in comma-roberta-base/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-2500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-3000
# Configuration saved in comma-roberta-base/checkpoint-3000/config.json
# Model weights saved in comma-roberta-base/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-3000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-3500
# Configuration saved in comma-roberta-base/checkpoint-3500/config.json
# Model weights saved in comma-roberta-base/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-3500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# wandb: Network error (ReadTimeout), entering retry loop.
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-4000
# Configuration saved in comma-roberta-base/checkpoint-4000/config.json
# Model weights saved in comma-roberta-base/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-4000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-4500
# Configuration saved in comma-roberta-base/checkpoint-4500/config.json
# Model weights saved in comma-roberta-base/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-4500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-5000
# Configuration saved in comma-roberta-base/checkpoint-5000/config.json
# Model weights saved in comma-roberta-base/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-5000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-5500
# Configuration saved in comma-roberta-base/checkpoint-5500/config.json
# Model weights saved in comma-roberta-base/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-5500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-6000
# Configuration saved in comma-roberta-base/checkpoint-6000/config.json
# Model weights saved in comma-roberta-base/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-6000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-6500
# Configuration saved in comma-roberta-base/checkpoint-6500/config.json
# Model weights saved in comma-roberta-base/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-6500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-7000
# Configuration saved in comma-roberta-base/checkpoint-7000/config.json
# Model weights saved in comma-roberta-base/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-7000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-7500
# Configuration saved in comma-roberta-base/checkpoint-7500/config.json
# Model weights saved in comma-roberta-base/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-7500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-8000
# Configuration saved in comma-roberta-base/checkpoint-8000/config.json
# Model weights saved in comma-roberta-base/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-8000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-8500
# Configuration saved in comma-roberta-base/checkpoint-8500/config.json
# Model weights saved in comma-roberta-base/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-8500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-9000
# Configuration saved in comma-roberta-base/checkpoint-9000/config.json
# Model weights saved in comma-roberta-base/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-9000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-9500
# Configuration saved in comma-roberta-base/checkpoint-9500/config.json
# Model weights saved in comma-roberta-base/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-9500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-10000
# Configuration saved in comma-roberta-base/checkpoint-10000/config.json
# Model weights saved in comma-roberta-base/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-10000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-10500
# Configuration saved in comma-roberta-base/checkpoint-10500/config.json
# Model weights saved in comma-roberta-base/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-10500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-11000
# Configuration saved in comma-roberta-base/checkpoint-11000/config.json
# Model weights saved in comma-roberta-base/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-11000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-11500
# Configuration saved in comma-roberta-base/checkpoint-11500/config.json
# Model weights saved in comma-roberta-base/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-11500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-12000
# Configuration saved in comma-roberta-base/checkpoint-12000/config.json
# Model weights saved in comma-roberta-base/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-12000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-12500
# Configuration saved in comma-roberta-base/checkpoint-12500/config.json
# Model weights saved in comma-roberta-base/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-12500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-13000
# Configuration saved in comma-roberta-base/checkpoint-13000/config.json
# Model weights saved in comma-roberta-base/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-13000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-13500
# Configuration saved in comma-roberta-base/checkpoint-13500/config.json
# Model weights saved in comma-roberta-base/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-13500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-14000
# Configuration saved in comma-roberta-base/checkpoint-14000/config.json
# Model weights saved in comma-roberta-base/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-14000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-14500
# Configuration saved in comma-roberta-base/checkpoint-14500/config.json
# Model weights saved in comma-roberta-base/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-14500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-15000
# Configuration saved in comma-roberta-base/checkpoint-15000/config.json
# Model weights saved in comma-roberta-base/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-15000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-15500
# Configuration saved in comma-roberta-base/checkpoint-15500/config.json
# Model weights saved in comma-roberta-base/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-15500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-16000
# Configuration saved in comma-roberta-base/checkpoint-16000/config.json
# Model weights saved in comma-roberta-base/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-16000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-16500
# Configuration saved in comma-roberta-base/checkpoint-16500/config.json
# Model weights saved in comma-roberta-base/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-16500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-17000
# Configuration saved in comma-roberta-base/checkpoint-17000/config.json
# Model weights saved in comma-roberta-base/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-17000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-17500
# Configuration saved in comma-roberta-base/checkpoint-17500/config.json
# Model weights saved in comma-roberta-base/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-17500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-18000
# Configuration saved in comma-roberta-base/checkpoint-18000/config.json
# Model weights saved in comma-roberta-base/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-18000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-18500
# Configuration saved in comma-roberta-base/checkpoint-18500/config.json
# Model weights saved in comma-roberta-base/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-18500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-19000
# Configuration saved in comma-roberta-base/checkpoint-19000/config.json
# Model weights saved in comma-roberta-base/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-19000/special_tokens_map.json
# ...
# tokenizer config file saved in comma-roberta-base/checkpoint-46500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-46500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-47000
# Configuration saved in comma-roberta-base/checkpoint-47000/config.json
# Model weights saved in comma-roberta-base/checkpoint-47000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-47000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-47000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-47500
# Configuration saved in comma-roberta-base/checkpoint-47500/config.json
# Model weights saved in comma-roberta-base/checkpoint-47500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-47500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-47500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-48000
# Configuration saved in comma-roberta-base/checkpoint-48000/config.json
# Model weights saved in comma-roberta-base/checkpoint-48000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-48000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-48000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-48500
# Configuration saved in comma-roberta-base/checkpoint-48500/config.json
# Model weights saved in comma-roberta-base/checkpoint-48500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-48500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-48500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-49000
# Configuration saved in comma-roberta-base/checkpoint-49000/config.json
# Model weights saved in comma-roberta-base/checkpoint-49000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-49000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-49000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-49500
# Configuration saved in comma-roberta-base/checkpoint-49500/config.json
# Model weights saved in comma-roberta-base/checkpoint-49500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-49500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-49500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-50000
# Configuration saved in comma-roberta-base/checkpoint-50000/config.json
# Model weights saved in comma-roberta-base/checkpoint-50000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-50000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-50000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-50500
# Configuration saved in comma-roberta-base/checkpoint-50500/config.json
# Model weights saved in comma-roberta-base/checkpoint-50500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-50500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-50500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-51000
# Configuration saved in comma-roberta-base/checkpoint-51000/config.json
# Model weights saved in comma-roberta-base/checkpoint-51000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-51000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-51000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-51500
# Configuration saved in comma-roberta-base/checkpoint-51500/config.json
# Model weights saved in comma-roberta-base/checkpoint-51500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-51500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-51500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-52000
# Configuration saved in comma-roberta-base/checkpoint-52000/config.json
# Model weights saved in comma-roberta-base/checkpoint-52000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-52000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-52000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-52500
# Configuration saved in comma-roberta-base/checkpoint-52500/config.json
# Model weights saved in comma-roberta-base/checkpoint-52500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-52500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-52500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-53000
# Configuration saved in comma-roberta-base/checkpoint-53000/config.json
# Model weights saved in comma-roberta-base/checkpoint-53000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-53000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-53000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-53500
# Configuration saved in comma-roberta-base/checkpoint-53500/config.json
# Model weights saved in comma-roberta-base/checkpoint-53500/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-53500/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-53500/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
# Saving model checkpoint to comma-roberta-base/checkpoint-54000
# Configuration saved in comma-roberta-base/checkpoint-54000/config.json
# Model weights saved in comma-roberta-base/checkpoint-54000/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base/checkpoint-54000/tokenizer_config.json
# Special tokens file saved in comma-roberta-base/checkpoint-54000/special_tokens_map.json
# /opt/conda/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=54170, training_loss=0.050950363251431, metrics={'train_runtime': 32047.6374, 'train_samples_per_second': 865.421, 'train_steps_per_second': 1.69, 'total_flos': 2.4190737124734285e+18, 'train_loss': 0.050950363251431, 'epoch': 5.0})

# %%
trainer.evaluate()
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `RobertaForTokenClassification.forward` and have been ignored: tags, tokens. If tags, tokens are not expected by `RobertaForTokenClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 30000
#   Batch size = 32
#     <div>
#
#       <progress value='118' max='118' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [118/118 00:30]
#     </div>
# {'eval_loss': 0.03436991572380066,
#  'eval_precision': 0.8730498066863771,
#  'eval_recall': 0.8613934702120498,
#  'eval_f1': 0.8671824702095215,
#  'eval_accuracy': 0.9825013578970082,
#  'eval_runtime': 48.3887,
#  'eval_samples_per_second': 619.979,
#  'eval_steps_per_second': 2.439,
#  'epoch': 5.0}

# %%
trainer.save_model("comma-" + model_checkpoint + "-3domains-more-data")
# Out:
# Saving model checkpoint to comma-roberta-base-3domains-more-data
# Configuration saved in comma-roberta-base-3domains-more-data/config.json
# Model weights saved in comma-roberta-base-3domains-more-data/pytorch_model.bin
# tokenizer config file saved in comma-roberta-base-3domains-more-data/tokenizer_config.json
# Special tokens file saved in comma-roberta-base-3domains-more-data/special_tokens_map.json
